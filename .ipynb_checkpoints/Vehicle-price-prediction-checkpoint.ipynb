# %% [markdown]
# # Vehicle price prediction
# * the main aim of this project is to predict the efficiency of a vehicle based on the year of manufacture, mileage, fuel-type, km-driven, transmission type

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import the dataset

# %%
df = pd.read_csv(r"C:\Users\manit\OneDrive\Documents\GitHub\data_science_project\Car-details.csv")
df.sample(15) #sample method return the random sample data from the dataset
# Out:
#                                         name  year  selling_price  km_driven  \
# 1563          Jaguar XF 2.0 Diesel Portfolio  2017        3200000      45000
# 5476              Mahindra Scorpio SLE BSIII  2013         600000     110000
# 838                  Tata Sumo Gold EX BSIII  2017         400000     140000
# 5324             Honda City i VTEC VX Option  2015         800000      50000
# 5603         Tata Nexon 1.2 Revotron XZ Plus  2018         850000      40000
# 3827                      Hyundai Elantra SX  2013         511000      90000
# 1265                      Honda City 1.5 EXI  2002          81000     161000
# 524                Chevrolet Sail 1.2 LS ABS  2016         400000      30000
# 4855                   Honda Amaze VX i-DTEC  2013         420000      40000
# 7592  Tata Tiago 2019-2020 XZ Plus Dual Tone  2019         450000       3500
# 3477              Ford Figo 1.2P Titanium MT  2016         388000      50000
# ...

# %% [markdown]
# # Data Cleaning
# * all the redundant and null valued data is removed

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7906 non-null   object
#  1   year           7906 non-null   int64
#  2   selling_price  7906 non-null   int64
#  3   km_driven      7906 non-null   int64
#  4   fuel           7906 non-null   object
#  5   seller_type    7906 non-null   object
#  6   transmission   7906 non-null   object
#  7   owner          7906 non-null   object
#  8   mileage        7906 non-null   object
#  9   engine         7906 non-null   object
#  10  max_power      7906 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7906 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 864.7+ KB

# %% [markdown]
# # Insights
